# %% [markdown]
# # Lokoja Flood Risk MCDA — Results Review
# This notebook loads the final hazard, risk, population and infrastructure exposure tables.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
headline = pd.read_csv(ROOT / 'data/processed/tables/05_Lokoja_Headline_Project_Results.csv')
headline

# %%
hazard = pd.read_csv(ROOT / 'data/processed/tables/Lokoja_Flood_Hazard_Area_Statistics.csv')
risk = pd.read_csv(ROOT / 'data/processed/tables/Lokoja_Final_Flood_Risk_Area_Statistics.csv')
population = pd.read_csv(ROOT / 'data/processed/tables/Lokoja_Population_by_Final_Flood_Risk_Class.csv')
hazard, risk, population
